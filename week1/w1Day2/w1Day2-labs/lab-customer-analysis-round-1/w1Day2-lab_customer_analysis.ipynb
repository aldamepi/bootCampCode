# %%
# Import the libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the files and Show the DataFrame's shapes

# %%
f1 = pd.read_csv('./files_for_lab/csv_files/file1.csv', index_col = False)
f2 = pd.read_csv('./files_for_lab/csv_files/file2.csv', index_col = False)
f3 = pd.read_csv('./files_for_lab/csv_files/file3.csv', index_col = False)

# Show the data frame
display(f1.head())
print(f1.shape)
display(f2.head())
print(f2.shape)
display(f3.head())
print(f3.shape)
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %% [markdown]
# # Standardize Header Names

# %%
header1 = list(f1.columns)
header2 = list(f2.columns)
header3 = list(f3.columns)
print(header1)
print(header3)
# Out:
# ['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type', 'Vehicle Class', 'Total Claim Amount']
# ['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type', 'Total Claim Amount', 'Vehicle Class']

# %%
def standard_header(head):
    new_header = []
    for h in head:
        #print(h)
        h = h.lower()
        #print(h)
        h = h.replace(' ','_')
        #print(h)
        new_header.append(h)
    return new_header

# ??? How to store the values directly into de list inside the for loop

# %%
header1 = standard_header(header1)
header2 = standard_header(header2)
header3 = standard_header(header3)
print(header1)
# Out:
# ['customer', 'st', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']

# %%
print(header2)
# Out:
# ['customer', 'st', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'total_claim_amount', 'policy_type', 'vehicle_class']

# %%
print(header3)
# Out:
# ['customer', 'state', 'customer_lifetime_value', 'education', 'gender', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'total_claim_amount', 'vehicle_class']

# %%
header1[1] = 'state'
header2[1] = 'state'
print(header1)
print(header2)
# Out:
# ['customer', 'state', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']
# ['customer', 'state', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'total_claim_amount', 'policy_type', 'vehicle_class']

# %%
print(header1==header2)
print(header2==header3)
print(header1==header3)
# Out:
# False
# False
# False

# %%
# Change the names of the columns to the standardize ones
f1.columns = header1
display(f1.head())
f2.columns = header2
display(f2.head())
f3.columns = header3
display(f3.head())
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %% [markdown]
# # Rearrange the columns in the DataFrame

# %%
# I am creating my own order of the columns
header1
# Out:
# ['customer',
#  'state',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
hh = ['customer','state','gender','education','customer_lifetime_value','policy_type','vehicle_class','income','monthly_premium_auto','number_of_open_complaints','total_claim_amount']
len(header1) == len(hh)
# Out:
# True

# %%
# Rearrange the columns of the files with the order in hh
f1 = f1[hh]
display(f1.head())
f2 = f2[hh]
display(f2.head())
f3 = f3[hh]
display(f3.head())
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#       policy_type  vehicle_class   income  monthly_premium_auto  \
# 0   Personal Auto  Four-Door Car      0.0                1000.0
# 1   Personal Auto  Four-Door Car      0.0                  94.0
# 2   Personal Auto   Two-Door Car  48767.0                 108.0
# 3  Corporate Auto            SUV      0.0                 106.0
# 4   Personal Auto  Four-Door Car  36357.0                  68.0
#
#   number_of_open_complaints  total_claim_amount
# 0                    1/0/00            2.704934
# ...

# %% [markdown]
# # Concatenate the three data frames

# %%
df = pd.concat([f1,f2,f3], axis = 0, ignore_index = True)

# %%
df.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#       policy_type  vehicle_class   income  monthly_premium_auto  \
# 0   Personal Auto  Four-Door Car      0.0                1000.0
# 1   Personal Auto  Four-Door Car      0.0                  94.0
# 2   Personal Auto   Two-Door Car  48767.0                 108.0
# 3  Corporate Auto            SUV      0.0                 106.0
# 4   Personal Auto  Four-Door Car  36357.0                  68.0
#
#   number_of_open_complaints  total_claim_amount
# 0                    1/0/00            2.704934
# ...

# %%
df.shape
# Out:
# (12074, 11)

# %%
len(df) == len(f1) + len (f2) + len(f3)
# Out:
# True

# %% [markdown]
# # Which columns are numerical

# %%
df.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#       policy_type  vehicle_class   income  monthly_premium_auto  \
# 0   Personal Auto  Four-Door Car      0.0                1000.0
# 1   Personal Auto  Four-Door Car      0.0                  94.0
# 2   Personal Auto   Two-Door Car  48767.0                 108.0
# 3  Corporate Auto            SUV      0.0                 106.0
# 4   Personal Auto  Four-Door Car  36357.0                  68.0
#
#   number_of_open_complaints  total_claim_amount
# 0                    1/0/00            2.704934
# ...

# %%
df.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# policy_type                   object
# vehicle_class                 object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# total_claim_amount           float64
# dtype: object

# %%
df._get_numeric_data()
# Out:
#         income  monthly_premium_auto  total_claim_amount
# 0          0.0                1000.0            2.704934
# 1          0.0                  94.0         1131.464935
# 2      48767.0                 108.0          566.472247
# 3          0.0                 106.0          529.881344
# 4      36357.0                  68.0           17.269323
# ...        ...                   ...                 ...
# 12069  71941.0                  73.0          198.234764
# 12070  21604.0                  79.0          379.200000
# 12071      0.0                  85.0          790.784983
# 12072  21941.0                  96.0          691.200000
# 12073      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
# I would also include customer_lifetime_value and number_of_open_complaints

# %% [markdown]
# # Which columns are categorical

# %%
df.select_dtypes('object')
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value     policy_type  vehicle_class  \
# 0                         NaN   Personal Auto  Four-Door Car
# 1                  697953.59%   Personal Auto  Four-Door Car
# 2                 1288743.17%   Personal Auto   Two-Door Car
# ...

# %% [markdown]
# # Understand the meaning of the columns

# %% [markdown]
# I do not understand the meaning of the columns

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Delete columns

# %%
# I get some previous information about the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer_lifetime_value    9130 non-null   object
#  5   policy_type                9137 non-null   object
#  6   vehicle_class              9137 non-null   object
#  7   income                     9137 non-null   float64
#  8   monthly_premium_auto       9137 non-null   float64
#  9   number_of_open_complaints  9137 non-null   object
#  10  total_claim_amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.0+ MB

# %%
df.isna().sum()
# Out:
# customer                     2937
# state                        2937
# gender                       3059
# education                    2937
# customer_lifetime_value      2944
# policy_type                  2937
# vehicle_class                2937
# income                       2937
# monthly_premium_auto         2937
# number_of_open_complaints    2937
# total_claim_amount           2937
# dtype: int64

# %%
df.drop(['education','number_of_open_complaints'], axis=1, inplace = True)
df.head()
# Out:
#   customer       state gender customer_lifetime_value     policy_type  \
# 0  RB50392  Washington    NaN                     NaN   Personal Auto
# 1  QZ44356     Arizona      F              697953.59%   Personal Auto
# 2  AI49188      Nevada      F             1288743.17%   Personal Auto
# 3  WW63253  California      M              764586.18%  Corporate Auto
# 4  GA49547  Washington      M              536307.65%   Personal Auto
#
#    vehicle_class   income  monthly_premium_auto  total_claim_amount
# 0  Four-Door Car      0.0                1000.0            2.704934
# 1  Four-Door Car      0.0                  94.0         1131.464935
# 2   Two-Door Car  48767.0                 108.0          566.472247
# 3            SUV      0.0                 106.0          529.881344
# 4  Four-Door Car  36357.0                  68.0           17.269323

# %% [markdown]
# ## Correct the values in customer lifetime value

# %%
df['customer_lifetime_value'].dtypes
# Out:
# dtype('O')

# %%
df['customer_lifetime_value'].isna().sum()
# Out:
# 2944

# %%
df['customer_lifetime_value'].head(20)
# Out:
# 0             NaN
# 1      697953.59%
# 2     1288743.17%
# 3      764586.18%
# 4      536307.65%
# 5      825629.78%
# 6      538089.86%
# 7      721610.03%
# 8     2412750.40%
# 9      738817.81%
# 10     473899.20%
# 11     819719.71%
# 12     879879.70%
# 13     881901.89%
# 14     538443.17%
# 15     746313.94%
# 16     256686.78%
# 17     394524.16%
# 18     571033.31%
# 19     816261.71%
# Name: customer_lifetime_value, dtype: object

# %%
df['customer_lifetime_value'].tail(20)
# Out:
# 12054    7501.661322
# 12055    11663.98572
# 12056    5133.397765
# 12057    8732.090534
# 12058    9424.256842
# 12059    5479.555081
# 12060    2114.738469
# 12061    4140.648654
# 12062    25464.82059
# 12063    5678.050167
# 12064     16261.5855
# 12065      19872.262
# 12066    4628.995325
# 12067    5032.165498
# 12068    4100.398533
# 12069    23405.98798
# 12070    3096.511217
# 12071    8163.890428
# 12072    7524.442436
# 12073    2611.836866
# Name: customer_lifetime_value, dtype: object

# %%
print(f1['customer_lifetime_value'].dtypes)
print(f2['customer_lifetime_value'].dtypes)
print(f3['customer_lifetime_value'].dtypes)
# Out:
# object
# object
# float64

# %%
right_rows = len(f1) + len(f2)
right_rows
# Out:
# 5004

# %%
new_column0 = df['customer_lifetime_value'][:5004].str.rstrip('%').astype('float') / 100.0
new_column0
# Out:
# 0              NaN
# 1        6979.5359
# 2       12887.4317
# 3        7645.8618
# 4        5363.0765
#            ...
# 4999     8471.4175
# 5000     5431.2191
# 5001     5689.6441
# 5002     3686.7238
# 5003     3992.5839
# Name: customer_lifetime_value, Length: 5004, dtype: float64

# %%
type(new_column0)
# Out:
# pandas.core.series.Series

# %%
#df[['customer_lifetime_value']][:5004].astype(np.string_).rstrip('%').astype('float') / 100.0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wh/b1t7_x71343d359xkfyw5n2m0000gn/T/ipykernel_14523/1794629030.py in <module>
# ----> 1 df[['customer_lifetime_value']][:5004].astype(np.string_).rstrip('%').astype('float') / 100.0
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rstrip'

# %%
new_column1 = df['customer_lifetime_value'][5004:].astype('float')
new_column1
# Out:
# 5004      3479.137523
# 5005      2502.637401
# 5006      3265.156348
# 5007      4455.843406
# 5008      7704.958480
#              ...
# 12069    23405.987980
# 12070     3096.511217
# 12071     8163.890428
# 12072     7524.442436
# 12073     2611.836866
# Name: customer_lifetime_value, Length: 7070, dtype: float64

# %%
df[['customer_lifetime_value']][5004:].astype('float')
# Out:
#        customer_lifetime_value
# 5004               3479.137523
# 5005               2502.637401
# 5006               3265.156348
# 5007               4455.843406
# 5008               7704.958480
# ...                        ...
# 12069             23405.987980
# 12070              3096.511217
# 12071              8163.890428
# 12072              7524.442436
# 12073              2611.836866
#
# [7070 rows x 1 columns]

# %%
#new_column = pd.concat(['new_column0','new_column1'])
#new_column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/wh/b1t7_x71343d359xkfyw5n2m0000gn/T/ipykernel_14523/4054759195.py in <module>
# ----> 1 new_column = pd.concat(['new_column0','new_column1'])
#       2 new_column
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# ...

# %%
#df['customer_lifetime_value'] = 
df['customer_lifetime_value'].astype(np.str_) #.rstrip('%').astype('float') * 100.0
# Out:
# 0                nan
# 1         697953.59%
# 2        1288743.17%
# 3         764586.18%
# 4         536307.65%
#             ...
# 12069    23405.98798
# 12070    3096.511217
# 12071    8163.890428
# 12072    7524.442436
# 12073    2611.836866
# Name: customer_lifetime_value, Length: 12074, dtype: object

# %%
df['customer_lifetime_value'].str.rstrip('%') #.astype('float') * 100.0
# Out:
# 0               NaN
# 1         697953.59
# 2        1288743.17
# 3         764586.18
# 4         536307.65
#             ...
# 12069           NaN
# 12070           NaN
# 12071           NaN
# 12072           NaN
# 12073           NaN
# Name: customer_lifetime_value, Length: 12074, dtype: object

# %%
new_column = [new_column0, new_column1]
new_column
# Out:
# [0              NaN
#  1        6979.5359
#  2       12887.4317
#  3        7645.8618
#  4        5363.0765
#             ...
#  4999     8471.4175
#  5000     5431.2191
#  5001     5689.6441
#  5002     3686.7238
#  5003     3992.5839
#  Name: customer_lifetime_value, Length: 5004, dtype: float64,
#  5004      3479.137523
#  5005      2502.637401
#  5006      3265.156348
#  5007      4455.843406
#  5008      7704.958480
#               ...
#  12069    23405.987980
#  12070     3096.511217
#  12071     8163.890428
#  12072     7524.442436
#  12073     2611.836866
#  Name: customer_lifetime_value, Length: 7070, dtype: float64]

# %%
type(new_column)
# Out:
# list

# %%
nc_CLV = pd.Series(new_column)
nc_CLV
# Out:
# 0    0              NaN
# 1        6979.5359
# 2       ...
# 1    5004      3479.137523
# 5005      2502.637401
# 50...
# dtype: object

# %%
new_clv = df.customer_lifetime_value.to_list()
new_clv
# Out:
# [nan,
#  '697953.59%',
#  '1288743.17%',
#  '764586.18%',
#  '536307.65%',
#  '825629.78%',
#  '538089.86%',
#  '721610.03%',
#  '2412750.40%',
#  '738817.81%',
#  '473899.20%',
#  '819719.71%',
#  '879879.70%',
#  '881901.89%',
#  '538443.17%',
#  '746313.94%',
#  '256686.78%',
#  '394524.16%',
#  '571033.31%',
#  '816261.71%',
#  '287205.13%',
#  '617710.93%',
#  '2412750.40%',
#  '245019.10%',
#  '239210.79%',
#  '580206.60%',
#  '394637.21%',
#  '916206.32%',
#  '1290256.01%',
#  '323536.05%',
#  '245458.35%',
#  '1897545.61%',
#  '471532.13%',
#  '473787.17%',
#  '493291.63%',
#  '574422.97%',
#  '1389173.57%',
#  '738097.67%',
#  '309003.41%',
#  '252163.31%',
#  '265206.18%',
#  '277104.50%',
#  '393900.64%',
#  '1223187.97%',
#  '495165.61%',
#  '1281910.29%',
#  '446851.05%',
#  '551434.40%',
#  '334387.53%',
#  '229447.89%',
#  '3670742.64%',
#  '3347334.95%',
#  '798343.17%',
#  '487938.48%',
#  '429399.73%',
#  '716439.55%',
#  '761951.58%',
#  '395800.28%',
# ...

# %%
type(new_clv[10000])
# Out:
# float

# %%
new_clv[10000]
# Out:
# 5876.373894

# %%
def correct_CLV(series):
    lst = series.to_list()
    lst0 = lst[:5004]
    lst1 = lst[5004:]
    elst0 = []
    elst1 = []
    for x in lst1: #0:
        x = str(x)
        print(x)
        x = x.rstrip('%')
        print(x)
        x = float(x)
        x = round(x / 100,4)
        print(x)
        elst0.append(x)
    for y in lst0: #1:
        print(y)
        y = round(y,4)
        elst1.append(y)
    newList = elst0 + elst1
    new_series = pd.series(newList)
    return newList

# %%
CLV = correct_CLV(new_clv[7000:7010])
CLV
# Out:
# 3133.018242
# 7123.082388
# 28435.64035
# 12741.84754
# 3176.865609
# 5470.060561
# 4582.647706
# 5350.214918
# 5580.916514
# 7048.544758
# [3133.0182,
#  7123.0824,
#  28435.6404,
#  12741.8475,
#  3176.8656,
#  5470.0606,
#  4582.6477,
#  5350.2149,
#  5580.9165,
#  7048.5448]

# %%
new_clv[:10]
# Out:
# [nan,
#  '697953.59%',
#  '1288743.17%',
#  '764586.18%',
#  '536307.65%',
#  '825629.78%',
#  '538089.86%',
#  '721610.03%',
#  '2412750.40%',
#  '738817.81%']

# %%
CLVser = pd.Series(CLV)
CLVser
# Out:
# 0     3133.0182
# 1     7123.0824
# 2    28435.6404
# 3    12741.8475
# 4     3176.8656
# 5     5470.0606
# 6     4582.6477
# 7     5350.2149
# 8     5580.9165
# 9     7048.5448
# dtype: float64

# %%
def correct_CLV(series):
    lst = series.to_list()
    lst0 = lst[:5004]
    lst1 = lst[5004:]
    elst0 = []
    elst1 = []
    for x in lst0:
        x = str(x)
        #print(x)
        x = x.rstrip('%')
        #print(x)
        x = float(x)
        x = round(x / 100,4)
        #print(x)
        elst0.append(x)
    for y in lst1:
        #y = float(y)
        y = round(y,4)
        elst1.append(y)
    newList = elst0 + elst1
    new_series = pd.Series(newList)
    return new_series

# %%
correctedCLV = correct_CLV(df.customer_lifetime_value)
correctedCLV
# Out:
# 0               NaN
# 1         6979.5359
# 2        12887.4317
# 3         7645.8618
# 4         5363.0765
#             ...
# 12069    23405.9880
# 12070     3096.5112
# 12071     8163.8904
# 12072     7524.4424
# 12073     2611.8369
# Length: 12074, dtype: float64

# %%
df.customer_lifetime_value = correctedCLV
df
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#        customer_lifetime_value     policy_type  vehicle_class   income  \
# 0                          NaN   Personal Auto  Four-Door Car      0.0
# 1                    6979.5359   Personal Auto  Four-Door Car      0.0
# 2                   12887.4317   Personal Auto   Two-Door Car  48767.0
# ...

# %% [markdown]
# # Check for duplicates

# %%
df.drop_duplicates()
df.shape
# Out:
# (12074, 11)

# %% [markdown]
# There are no duplicates

# %% [markdown]
# # Filter outs customer with income <= 0

# %%
df.head()
# Out:
#   customer       state gender             education  customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                      NaN
# 1  QZ44356     Arizona      F              Bachelor                6979.5359
# 2  AI49188      Nevada      F              Bachelor               12887.4317
# 3  WW63253  California      M              Bachelor                7645.8618
# 4  GA49547  Washington      M  High School or Below                5363.0765
#
#       policy_type  vehicle_class   income  monthly_premium_auto  \
# 0   Personal Auto  Four-Door Car      0.0                1000.0
# 1   Personal Auto  Four-Door Car      0.0                  94.0
# 2   Personal Auto   Two-Door Car  48767.0                 108.0
# 3  Corporate Auto            SUV      0.0                 106.0
# 4   Personal Auto  Four-Door Car  36357.0                  68.0
#
#   number_of_open_complaints  total_claim_amount
# 0                    1/0/00            2.704934
# ...

# %%
df[df.income <= 0]
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 7      CF85061     Arizona      M                Master
# 10     SX51350  California      M               College
# ...        ...         ...    ...                   ...
# 12063  WZ45103  California      F              Bachelor
# 12065  RX91025  California      M  High School or Below
# 12066  AC13887  California      M              Bachelor
# 12071  TD14365  California      M              Bachelor
# 12073  Y167826  California      M               College
#
#        customer_lifetime_value     policy_type  vehicle_class  income  \
# 0                          NaN   Personal Auto  Four-Door Car     0.0
# 1                    6979.5359   Personal Auto  Four-Door Car     0.0
# 3                    7645.8618  Corporate Auto            SUV     0.0
# ...

# %%
len(df[df.income <= 0])
# Out:
# 2294

# %%
# I test the float data type

# %%
a = 75.4

# %%
type(a)
# Out:
# float

# %%
b = 43,2

# %%
type(b)
# Out:
# tuple

# %%
c = 'hola'

# %%
type(c)
# Out:
# str

# %%
# I study the result of functon dtypes and pandas series

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
typ = df.dtypes
typ
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# policy_type                   object
# vehicle_class                 object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# total_claim_amount           float64
# dtype: object

# %%
typ[:4]
# Out:
# customer     object
# state        object
# gender       object
# education    object
# dtype: object

# %%
typ['customer']
# Out:
# dtype('O')

# %%
typ['income']
# Out:
# dtype('float64')
